# %% [markdown]
# # Relatório de Análise V - Criação e exclusão de variáveis

# %% [markdown]
# ## Criando Novas Variáveis

# %% [markdown]
# **Tarefa**: Adicionar variáveis relacionadas com o preço bruto (valor+condominio+iptu), valor por metro$^2$ e preço bruto por metro$^2$

# %%
import pandas as pd

# %%
dados = pd.read_csv('aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %%
dados.shape[1]
# Out:
# 11

# %%
dados.head(10)

# %%
dados.pop('Valor m2')
# Out:
# 0        42.50
# 1        70.00
# 2        53.33
# 3        16.67
# 4        26.00
#          ...
# 21821    12.86
# 21822    29.63
# 21823    23.08
# 21824    29.17
# 21825    42.86
# Name: Valor m2, Length: 21826, dtype: float64

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU Tipo Agregado
# 0   1700.0       500.0  60.0   Apartamento
# 1   7000.0         0.0   0.0          Casa
# 2    800.0       390.0  20.0   Apartamento
# 3    800.0       230.0   0.0   Apartamento
# 4   1300.0       301.0  17.0   Apartamento
# 5  22000.0         0.0   0.0          Casa
# 6   1000.0         0.0   0.0          Casa
# 7   1500.0       642.0  74.0   Apartamento
# 8   1500.0       455.0  14.0   Apartamento
# 9   2000.0       561.0  50.0   Apartamento

# %%
dados.pop('Tipo Agregado')
# Out:
# 0        Apartamento
# 1               Casa
# 2        Apartamento
# 3        Apartamento
# 4        Apartamento
#             ...
# 21821    Apartamento
# 21822    Apartamento
# 21823    Apartamento
# 21824    Apartamento
# 21825    Apartamento
# Name: Tipo Agregado, Length: 21826, dtype: object

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU
# 0   1700.0       500.0  60.0
# 1   7000.0         0.0   0.0
# 2    800.0       390.0  20.0
# 3    800.0       230.0   0.0
# 4   1300.0       301.0  17.0
# 5  22000.0         0.0   0.0
# 6   1000.0         0.0   0.0
# 7   1500.0       642.0  74.0
# 8   1500.0       455.0  14.0
# 9   2000.0       561.0  50.0

# %%
dados['Preço Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Preço Bruto
# 0      1700.0       500.0  60.0       2260.0
# 1      7000.0         0.0   0.0       7000.0
# 2       800.0       390.0  20.0       1210.0
# 3       800.0       230.0   0.0       1030.0
# 4      1300.0       301.0  17.0       1618.0
# ...       ...         ...   ...          ...
# 21821   900.0       490.0  48.0       1438.0
# 21822   800.0       350.0  25.0       1175.0
# 21823  1800.0       800.0  40.0       2640.0
# 21824  1400.0       509.0  37.0       1946.0
# 21825  3000.0       760.0   0.0       3760.0
#
# [21826 rows x 10 columns]

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']

# %%
dados['Valor m2'] = dados['Valor m2'].round(1)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Preço Bruto  Valor m2
# 0      1700.0       500.0  60.0       2260.0      42.5
# 1      7000.0         0.0   0.0       7000.0      70.0
# 2       800.0       390.0  20.0       1210.0      53.3
# 3       800.0       230.0   0.0       1030.0      16.7
# 4      1300.0       301.0  17.0       1618.0      26.0
# ...       ...         ...   ...          ...       ...
# 21821   900.0       490.0  48.0       1438.0      12.9
# 21822   800.0       350.0  25.0       1175.0      29.6
# 21823  1800.0       800.0  40.0       2640.0      23.1
# 21824  1400.0       509.0  37.0       1946.0      29.2
# 21825  3000.0       760.0   0.0       3760.0      42.9
#
# [21826 rows x 11 columns]

# %%
dados['Preço Bruto m2'] = dados['Preço Bruto'] / dados['Area']

# %%
dados['Preço Bruto m2'] = dados['Preço Bruto m2'].round(1)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Preço Bruto  Valor m2  Preço Bruto m2
# 0      1700.0       500.0  60.0       2260.0      42.5            56.5
# 1      7000.0         0.0   0.0       7000.0      70.0            70.0
# 2       800.0       390.0  20.0       1210.0      53.3            80.7
# 3       800.0       230.0   0.0       1030.0      16.7            21.5
# 4      1300.0       301.0  17.0       1618.0      26.0            32.4
# ...       ...         ...   ...          ...       ...             ...
# 21821   900.0       490.0  48.0       1438.0      12.9            20.5
# 21822   800.0       350.0  25.0       1175.0      29.6            43.5
# 21823  1800.0       800.0  40.0       2640.0      23.1            33.8
# 21824  1400.0       509.0  37.0       1946.0      29.2            40.5
# 21825  3000.0       760.0   0.0       3760.0      42.9            53.7
#
# [21826 rows x 12 columns]

# %% [markdown]
# **Tarefa**: Criar uma varíavel que defina se o imóvel é casa ou apartamento

# %%
dados['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Vila'], dtype=object)

# %%
casa = ['Quitinete', 'Casa de Condomínio', 'Casa de Vila', 'Casa']
casa
# Out:
# ['Quitinete', 'Casa de Condomínio', 'Casa de Vila', 'Casa']

# %%
dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')
# Out:
# 0               Casa
# 1               Casa
# 2        Apartamento
# 3        Apartamento
# 4        Apartamento
#             ...
# 21821    Apartamento
# 21822           Casa
# 21823    Apartamento
# 21824    Apartamento
# 21825    Apartamento
# Name: Tipo, Length: 21826, dtype: object

# %%
dados['Classe'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados['Valor'].apply(lambda x: x*5.2)
# Out:
# 0         8840.0
# 1        36400.0
# 2         4160.0
# 3         4160.0
# 4         6760.0
#           ...
# 21821     4680.0
# 21822     4160.0
# 21823     9360.0
# 21824     7280.0
# 21825    15600.0
# Name: Valor, Length: 21826, dtype: float64

# %%
dados.head(20)
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete               Copacabana        1      0       0    40
# 1                 Casa          Jardim Botânico        2      0       1   100
# 2          Apartamento                   Centro        1      0       0    15
# 3          Apartamento             Higienópolis        1      0       0    48
# 4          Apartamento                 Cachambi        2      0       0    50
# 5   Casa de Condomínio          Barra da Tijuca        5      4       5   750
# 6   Casa de Condomínio                    Ramos        2      2       0    65
# 7          Apartamento                   Grajaú        2      1       0    70
# 8          Apartamento      Lins de Vasconcelos        3      1       1    90
# 9          Apartamento               Copacabana        1      0       1    40
# 10           Quitinete               Copacabana        1      0       0    27
# 11         Apartamento               Copacabana        4      3       1   243
# 12  Casa de Condomínio                  Taquara        3      1       1   115
# 13         Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 14         Apartamento          Barra da Tijuca        2      1       1    67
# 15         Apartamento                   Tijuca        2      1       0   110
# 16  Casa de Condomínio          Barra da Tijuca        4      3       2   466
# 17         Apartamento                   Olaria        3      1       0    68
# 18         Apartamento                   Tijuca        2      1       0    78
# 19         Apartamento                  Ipanema        3      1       1   125
#
#       Valor  Condominio   IPTU  Preço Bruto  Valor m2  Preço Bruto m2  \
# 0    1700.0       500.0   60.0       2260.0      42.5            56.5
# 1    7000.0         0.0    0.0       7000.0      70.0            70.0
# 2     800.0       390.0   20.0       1210.0      53.3            80.7
# 3     800.0       230.0    0.0       1030.0      16.7            21.5
# 4    1300.0       301.0   17.0       1618.0      26.0            32.4
# 5   22000.0         0.0    0.0      22000.0      29.3            29.3
# 6    1000.0         0.0    0.0       1000.0      15.4            15.4
# 7    1500.0       642.0   74.0       2216.0      21.4            31.7
# 8    1500.0       455.0   14.0       1969.0      16.7            21.9
# 9    2000.0       561.0   50.0       2611.0      50.0            65.3
# 10   1800.0       501.0    0.0       2301.0      66.7            85.2
# 11  13000.0      2000.0  803.0      15803.0      53.5            65.0
# 12   2000.0         0.0    0.0       2000.0      17.4            17.4
# 13    950.0       300.0   28.0       1278.0      17.6            23.7
# 14   1700.0       589.0  147.0       2436.0      25.4            36.4
# 15   1900.0       700.0  138.0       2738.0      17.3            24.9
# 16   7500.0      2695.0    0.0      10195.0      16.1            21.9
# 17   1000.0       670.0    0.0       1670.0      14.7            24.6
# 18   2000.0       700.0    0.0       2700.0      25.6            34.6
# 19   7000.0      2100.0  463.0       9563.0      56.0            76.5
#
#          Classe
# 0          Casa
# 1          Casa
# 2   Apartamento
# 3   Apartamento
# 4   Apartamento
# 5          Casa
# 6          Casa
# 7   Apartamento
# 8   Apartamento
# 9   Apartamento
# 10         Casa
# 11  Apartamento
# 12         Casa
# 13  Apartamento
# 14  Apartamento
# 15  Apartamento
# 16         Casa
# 17  Apartamento
# 18  Apartamento
# 19  Apartamento

# %% [markdown]
# ## Excluindo Variáveis

# %% [markdown]
# **Tarefa**: O IPTU é informado para alguns imóveis e para outros não, fazendo com que o valor bruto não seja confiável. Assim, seria interessante excluir as variáveis que são obtidas com contribuição do IPTU.

# %%
#criar um dataframe auxiliar para testar e depois fazer as modificacoes no principal
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Preço Bruto  Valor m2  Preço Bruto m2  \
# 0      1700.0       500.0  60.0       2260.0      42.5            56.5
# 1      7000.0         0.0   0.0       7000.0      70.0            70.0
# 2       800.0       390.0  20.0       1210.0      53.3            80.7
# 3       800.0       230.0   0.0       1030.0      16.7            21.5
# 4      1300.0       301.0  17.0       1618.0      26.0            32.4
# ...       ...         ...   ...          ...       ...             ...
# 21821   900.0       490.0  48.0       1438.0      12.9            20.5
# 21822   800.0       350.0  25.0       1175.0      29.6            43.5
# 21823  1800.0       800.0  40.0       2640.0      23.1            33.8
# 21824  1400.0       509.0  37.0       1946.0      29.2            40.5
# 21825  3000.0       760.0   0.0       3760.0      42.9            53.7
#
#             Classe
# 0             Casa
# 1             Casa
# 2      Apartamento
# 3      Apartamento
# 4      Apartamento
# ...            ...
# 21821  Apartamento
# 21822         Casa
# 21823  Apartamento
# 21824  Apartamento
# 21825  Apartamento
#
# [21826 rows x 13 columns]

# %%
dados_aux = dados.copy()
dados_aux
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Preço Bruto  Valor m2  Preço Bruto m2  \
# 0      1700.0       500.0  60.0       2260.0      42.5            56.5
# 1      7000.0         0.0   0.0       7000.0      70.0            70.0
# 2       800.0       390.0  20.0       1210.0      53.3            80.7
# 3       800.0       230.0   0.0       1030.0      16.7            21.5
# 4      1300.0       301.0  17.0       1618.0      26.0            32.4
# ...       ...         ...   ...          ...       ...             ...
# 21821   900.0       490.0  48.0       1438.0      12.9            20.5
# 21822   800.0       350.0  25.0       1175.0      29.6            43.5
# 21823  1800.0       800.0  40.0       2640.0      23.1            33.8
# 21824  1400.0       509.0  37.0       1946.0      29.2            40.5
# 21825  3000.0       760.0   0.0       3760.0      42.9            53.7
#
#             Classe
# 0             Casa
# 1             Casa
# 2      Apartamento
# 3      Apartamento
# 4      Apartamento
# ...            ...
# 21821  Apartamento
# 21822         Casa
# 21823  Apartamento
# 21824  Apartamento
# 21825  Apartamento
#
# [21826 rows x 13 columns]

# %%
dados_aux.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Preço Bruto  Valor m2  Preço Bruto m2  \
# 0   1700.0       500.0  60.0       2260.0      42.5            56.5
# 1   7000.0         0.0   0.0       7000.0      70.0            70.0
# 2    800.0       390.0  20.0       1210.0      53.3            80.7
# 3    800.0       230.0   0.0       1030.0      16.7            21.5
# 4   1300.0       301.0  17.0       1618.0      26.0            32.4
# 5  22000.0         0.0   0.0      22000.0      29.3            29.3
# 6   1000.0         0.0   0.0       1000.0      15.4            15.4
# 7   1500.0       642.0  74.0       2216.0      21.4            31.7
# 8   1500.0       455.0  14.0       1969.0      16.7            21.9
# 9   2000.0       561.0  50.0       2611.0      50.0            65.3
#
#         Classe
# 0         Casa
# 1         Casa
# 2  Apartamento
# 3  Apartamento
# 4  Apartamento
# 5         Casa
# 6         Casa
# 7  Apartamento
# 8  Apartamento
# 9  Apartamento

# %%
del dados_aux['Preço Bruto']

# %%
dados_aux.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2  Preço Bruto m2       Classe
# 0   1700.0       500.0  60.0      42.5            56.5         Casa
# 1   7000.0         0.0   0.0      70.0            70.0         Casa
# 2    800.0       390.0  20.0      53.3            80.7  Apartamento
# 3    800.0       230.0   0.0      16.7            21.5  Apartamento
# 4   1300.0       301.0  17.0      26.0            32.4  Apartamento
# 5  22000.0         0.0   0.0      29.3            29.3         Casa
# 6   1000.0         0.0   0.0      15.4            15.4         Casa
# 7   1500.0       642.0  74.0      21.4            31.7  Apartamento
# 8   1500.0       455.0  14.0      16.7            21.9  Apartamento
# 9   2000.0       561.0  50.0      50.0            65.3  Apartamento

# %%
dados_aux.pop('Preço Bruto m2')
# Out:
# 0        56.5
# 1        70.0
# 2        80.7
# 3        21.5
# 4        32.4
#          ...
# 21821    20.5
# 21822    43.5
# 21823    33.8
# 21824    40.5
# 21825    53.7
# Name: Preço Bruto m2, Length: 21826, dtype: float64

# %%
dados_aux
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2       Classe
# 0      1700.0       500.0  60.0      42.5         Casa
# 1      7000.0         0.0   0.0      70.0         Casa
# 2       800.0       390.0  20.0      53.3  Apartamento
# 3       800.0       230.0   0.0      16.7  Apartamento
# 4      1300.0       301.0  17.0      26.0  Apartamento
# ...       ...         ...   ...       ...          ...
# 21821   900.0       490.0  48.0      12.9  Apartamento
# 21822   800.0       350.0  25.0      29.6         Casa
# 21823  1800.0       800.0  40.0      23.1  Apartamento
# 21824  1400.0       509.0  37.0      29.2  Apartamento
# 21825  3000.0       760.0   0.0      42.9  Apartamento
#
# [21826 rows x 11 columns]

# %%
dados_aux.drop(['Valor m2', 'Classe'], axis=1, inplace=True)

# %%
dados_aux.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 4       301.0  17.0

# %%
dados_aux.drop(['Tipo'], axis=1)
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                Copacabana        1      0       0    40  1700.0       500.0
# 1           Jardim Botânico        2      0       1   100  7000.0         0.0
# 2                    Centro        1      0       0    15   800.0       390.0
# 3              Higienópolis        1      0       0    48   800.0       230.0
# 4                  Cachambi        2      0       0    50  1300.0       301.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 21821                 Méier        2      0       0    70   900.0       490.0
# 21822                Centro        0      0       0    27   800.0       350.0
# 21823           Jacarepaguá        3      1       2    78  1800.0       800.0
# 21824  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 21825                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      60.0
# 1       0.0
# 2      20.0
# 3       0.0
# 4      17.0
# ...     ...
# 21821  48.0
# 21822  25.0
# 21823  40.0
# 21824  37.0
# 21825   0.0
#
# [21826 rows x 8 columns]

# %%
dados_aux.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU
# 0   1700.0       500.0  60.0
# 1   7000.0         0.0   0.0
# 2    800.0       390.0  20.0
# 3    800.0       230.0   0.0
# 4   1300.0       301.0  17.0
# 5  22000.0         0.0   0.0
# 6   1000.0         0.0   0.0
# 7   1500.0       642.0  74.0
# 8   1500.0       455.0  14.0
# 9   2000.0       561.0  50.0

# %% [markdown]
# # Relatório de Análise VI - Agrupamentos e estatística básica

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('aluguel_residencial.csv', sep = ';')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# 1      7000.0         0.0   0.0     70.00          Casa
# 2       800.0       390.0  20.0     53.33   Apartamento
# 3       800.0       230.0   0.0     16.67   Apartamento
# 4      1300.0       301.0  17.0     26.00   Apartamento
# ...       ...         ...   ...       ...           ...
# 21821   900.0       490.0  48.0     12.86   Apartamento
# 21822   800.0       350.0  25.0     29.63   Apartamento
# 21823  1800.0       800.0  40.0     23.08   Apartamento
# 21824  1400.0       509.0  37.0     29.17   Apartamento
# 21825  3000.0       760.0   0.0     42.86   Apartamento
#
# [21826 rows x 11 columns]

# %%
dados.nunique()
# Out:
# Tipo                5
# Bairro            152
# Quartos            14
# Vagas              17
# Suites             10
# Area              613
# Valor             537
# Condominio       2379
# IPTU             1759
# Valor m2         3406
# Tipo Agregado       2
# dtype: int64

# %%
dados['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Vila'], dtype=object)

# %% [markdown]
# #### https://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-stats

# %% [markdown]
# **Tarefa**: Valor médio de aluguel por bairros específicos

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
dados['Valor'].hist(bins=20)

# %%
dados[['Valor']].boxplot()

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados[selecao]
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete       Copacabana        1      0       0    40
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9             Apartamento       Copacabana        1      0       1    40
# 10              Quitinete       Copacabana        1      0       0    27
# 11            Apartamento       Copacabana        4      3       1   243
# ...                   ...              ...      ...    ...     ...   ...
# 21816         Apartamento           Leblon        3      0       1    80
# 21817         Apartamento          Ipanema        3      1       2   150
# 21818         Apartamento           Tijuca        1      0       0    28
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 21825         Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0       1700.0       500.0    60.0     42.50   Apartamento
# 5      22000.0         0.0     0.0     29.33          Casa
# 9       2000.0       561.0    50.0     50.00   Apartamento
# 10      1800.0       501.0     0.0     66.67   Apartamento
# 11     13000.0      2000.0   803.0     53.50   Apartamento
# ...        ...         ...     ...       ...           ...
# 21816   3000.0      1010.0   249.0     37.50   Apartamento
# 21817  15000.0      1400.0   600.0    100.00   Apartamento
# 21818   1000.0       360.0    25.0     35.71   Apartamento
# 21820  15000.0      1711.0  2332.0     33.33          Casa
# 21825   3000.0       760.0     0.0     42.86   Apartamento
#
# [12216 rows x 11 columns]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
#               ...
# 13855          Bancários
# 15277         Cavalcanti
# 15280       Rio da Prata
# 15412      Cidade Jardim
# 16428        Coelho Neto
# Name: Bairro, Length: 152, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Abolição': [1553, 3184, 6655, 6951, 7634, 10138, 13165, 14187, 16054, 16639, 17139, 18797, 18805, 20106, 21387], 'Alto da Boa Vista': [2201, 12039, 12556, 13240, 13438, 14518], 'Anchieta': [3017, 8880, 15660, 17811], 'Andaraí': [384, 452, 514, 613, 790, 846, 854, 996, 1191, 1416, 1421, 1685, 1912, 2014, 2683, 3137, 3216, 3489, 3578, 3738, 3856, 4227, 4572, 4773, 4876, 4883, 4961, 5545, 5753, 5990, 6232, 6450, 6529, 6911, 7168, 7408, 7889, 7890, 8064, 8430, 9190, 9290, 9334, 9380, 9713, 9929, 10104, 10255, 10275, 10859, 10940, 10947, 11079, 11516, 11818, 12292, 12762, 13243, 13385, 13389, 13769, 13897, 13931, 13938, 14214, 14592, 14668, 15915, 16009, 16504, 16509, 16599, 16654, 17510, 17769, 17794, 17913, 18212, 18433, 18754, 18888, 18918, 19041, 19668, 19750, 19770, 20100, 20219, 20516, 20866, 21028, 21074, 21114, 21326, 21455, 21543, 21582], 'Anil': [241, 572, 604, 1227, 1632, 1664, 1789, 1932, 2127, 2378, 3586, 3675, 3860, 4153, 4369, 4651, 4769, 4790, 5261, 5340, 5660, 6130, 6150, 6329, 6367, 6483, 6598, 6870, 6923, 7044, 7058, 7430, 7522, 8100, 8153, 8791, 9499, 9631, 9930, 10162, 10321, 10576, 10631, 11953, 11960, 12478, 13189, 13396, 13398, 13415, 14063, 14376, 14528, 14873, 15512, 16581, 16660, 16761, 17527, 17804, 18189, 18323, 18523, 19452, 19556, 19707, 19778, 21131, 21251, 21663, 21717], 'Arpoador': [2775, 3015, 3185, 3350, 4527, 9531, 13867, 14115, 14816, 16538, 18475, 18675], 'Bancários': [13855, 14779, 15906, 20377], 'Bangu': [1292, 1684, 1703, 2133, 3863, 3956, 4080, 7364, 10490, 10528, 10542, 11205, 11424, 11515, 11862, 13479, 14602, 17877, 18182, 20479], 'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Barra de Guaratiba': [3676, 10098, 19495, 20876], 'Benfica': [100, 5724, 11274, 18264, 19201], 'Bento Ribeiro': [2250, 2951, 2984, 5173, 6008, 7440, 9878, 10183, 10949, 13094, 13457, 13624, 13761, 14179, 15796, 15837, 18395, 19026, 20159, 20901, 21371, 21633, 21793], 'Bonsucesso': [67, 264, 367, 714, 918, 1288, 1459, 1512, 2064, 2219, 2668, 2678, 3058, 3233, 3258, 4130, 4259, 4353, 4925, 5140, 5451, 5630, 6731, 6866, 7584, 7733, 7977, 8607, 9784, 9888, 10037, 10430, 11447, 11863, 12338, 12356, 12371, 12905, 12923, 14931, 14942, 14959, 15378, 15983, 16148, 16464, 16610, 16889, 16960, 17022, 17420, 17786, 18086, 18890, 18970, 18994, 19652, 20593, 20926], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 2197, 2242, 2247, 2297, 2352, 2381, 2396, 2413, 2431, 2433, 2470, 2509, 2519, 2532, 2580, ...], 'Braz de Pina': [873, 3995, 4290, 5975, 6812, 6845, 7242, 9121, 9292, 12051, 12242, 12994, 14164, 15111, 15726, 15893, 17658, 18230, 19599, 19655], 'Cachambi': [4, 56, 247, 252, 525, 629, 1389, 1683, 1862, 1949, 2087, 2178, 2556, 2633, 2889, 3009, 3045, 3080, 3755, 4060, 4161, 4195, 4204, 4398, 4446, 4635, 4638, 5272, 5280, 5292, 5308, 5455, 5523, 5572, 5749, 5862, 5919, 5987, 5996, 6173, 6176, 6239, 6378, 6386, 6485, 6600, 6771, 6832, 6850, 7315, 7423, 7441, 7625, 7737, 7907, 8014, 8046, 8066, 8200, 8217, 8600, 8685, 8896, 8904, 8944, 9119, 9123, 9232, 9476, 9578, 9582, 9682, 9855, 10187, 10194, 10353, 10783, 10813, 11075, 11090, 11356, ...

# %%
grupo_bairro.groups['Flamengo']
# Out:
# Int64Index([   78,   138,   218,   284,   321,   347,   356,   361,   369,
#               393,
#             ...
#             21527, 21560, 21581, 21629, 21680, 21704, 21728, 21731, 21740,
#             21794],
#            dtype='int64', length=714)

# %%
grupo_bairro.groups['Barra da Tijuca']
# Out:
# Int64Index([    5,    14,    16,    21,    30,    32,    35,    42,    43,
#                60,
#             ...
#             21769, 21771, 21774, 21782, 21800, 21801, 21811, 21812, 21813,
#             21820],
#            dtype='int64', length=3863)

# %%
for bairro, data in grupo_bairro:
    print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Abolição -> 1195.3333333333333
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 875.0
# Andaraí -> 1464.7113402061855
# Anil -> 2048.8732394366198
# Arpoador -> 12923.916666666666
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.552938130986
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.8695652173913
# Bonsucesso -> 1225.9322033898304
# Botafogo -> 8791.828178694159
# Braz de Pina -> 1115.0
# Cachambi -> 1157.1742424242425
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1037.3333333333333
# Campo Grande -> 1267.71714922049
# Cascadura -> 948.7096774193549
# Catete -> 2267.0625
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.7521865889212
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.4285714285713
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.677004538578
# Cordovil -> 905.5555555555555
# Cosme Velho -> 5343.548387096775
# Cosmos -> 658.3333333333334
# Curicica -> 1514.5657894736842
# Del Castilho -> 1261.304347826087
# Encantado -> 1050.0
# Engenho Novo -> 1035.8252427184466
# Engenho da Rainha -> 883.5714285714286
# Engenho de Dentro -> 1166.3513513513512
# Estácio -> 1233.9130434782608
# Flamengo -> 4113.526610644258
# Freguesia (Ilha do Governador) -> 1720.0
# Freguesia (Jacarepaguá) -> 4966.666666666667
# Fátima -> 956.6666666666666
# Gamboa -> 1116.6666666666667
# Gardênia Azul -> 761.1111111111111
# Glória -> 2467.2897196261683
# Grajaú -> 2038.6206896551723
# Guadalupe -> 700.0
# Guaratiba -> 1232.258064516129
# Gávea -> 6563.688372093024
# Higienópolis -> 1006.25
# Honório Gurgel -> 628.5714285714286
# Humaitá -> 3802.3101265822784
# Icaraí -> 2393.75
# Ilha do Governador -> 1728.0
# Inhaúma -> 821.4285714285714
# Inhoaíba -> 725.0
# Ipanema -> 9352.001133786847
# Irajá -> 1096.012658227848
# Itanhangá -> 9341.269841269841
# Jabour -> 723.3333333333334
# Jacarepaguá -> 2046.9877551020409
# Jacaré -> 1200.0
# Jardim América -> 714.2857142857143
# Jardim Botânico -> 8722.357414448668
# Jardim Carioca -> 2211.1111111111113
# Jardim Guanabara -> 2124.6875
# Jardim Oceânico -> 7626.086956521739
# Jardim Sulacap -> 1176.6666666666667
# Joá -> 16773.478260869564
# Lagoa -> 8147.075819672131
# Lapa -> 1488.7777777777778
# Laranjeiras -> 3555.2776470588237
# Largo do Machado -> 1880.0
# Leblon -> 8746.344992050874
# Leme -> 3944.759825327511
# Lins de Vasconcelos -> 1086.1702127659576
# Madureira -> 1017.6595744680851
# Magalhães Bastos -> 640.0
# Maracanã -> 1945.4961240310076
# Marechal Hermes -> 844.4444444444445
# Maria da Graça -> 1073.3333333333333
# Moneró -> 1900.0
# Méier -> 1355.8745098039215
# Olaria -> 1016.5625
# Oswaldo Cruz -> 823.8888888888889
# Paciência -> 580.0
# Padre Miguel -> 786.25
# Paquetá -> 10550.0
# Parada de Lucas -> 1062.5
# Parque Anchieta -> 1287.5
# Pavuna -> 648.9473684210526
# Pechincha -> 1357.4257425742574
# Pedra de Guaratiba -> 1082.1052631578948
# Penha -> 1023.3333333333334
# Penha Circular -> 1160.0
# Península -> 7061.538461538462
# Piedade -> 956.5384615384615
# Pilares -> 1077.5
# Pitangueiras -> 2725.0
# Portuguesa -> 1272.7272727272727
# Praia da Bandeira -> 1300.0
# Praça Seca -> 998.4146341463414
# Praça da Bandeira -> 1358.723404255319
# Quintino Bocaiúva -> 924.6666666666666
# Ramos -> 958.0
# Realengo -> 908.3333333333334
# Recreio dos Bandeirantes -> 3736.6130988477867
# Riachuelo -> 1143.9024390243903
# Ribeira -> 1420.0
# Rio Comprido -> 1610.240506329114
# Rio da Prata -> 1300.0
# Rocha -> 1086.842105263158
# Rocha Miranda -> 877.0
# Sampaio -> 937.5
# Santa Cruz -> 734.2857142857143
# Santa Teresa -> 2713.3333333333335
# Santo Cristo -> 1225.0
# Santíssimo -> 756.25
# Saúde -> 950.0
# Senador Camará -> 600.0
# Senador Vasconcelos -> 867.3529411764706
# São Conrado -> 8780.88803088803
# São Cristóvão -> 1391.71875
# São Francisco Xavier -> 1237.2413793103449
# Tanque -> 1335.7142857142858
# Taquara -> 1642.140350877193
# Tauá -> 1340.0
# Tijuca -> 2043.52
# Todos os Santos -> 1243.076923076923
# Tomás Coelho -> 737.0
# Turiaçu -> 700.0
# Urca -> 7925.958904109589
# Usina -> 1520.0
# Vargem Grande -> 3358.1666666666665
# Vargem Pequena -> 2703.480769230769
# Vaz Lobo -> 845.0
# Vicente de Carvalho -> 1075.7142857142858
# Vidigal -> 2600.0
# Vigário Geral -> 970.0
# Vila Isabel -> 1560.8333333333333
# Vila Kosmos -> 1311.8181818181818
# Vila Militar -> 500.0
# Vila Valqueire -> 1769.5833333333333
# Vila da Penha -> 1260.576923076923
# Vista Alegre -> 1114.375
# Zumbi -> 2150.0
# Água Santa -> 861.1111111111111

# %%
grupo_bairro[['Valor']].mean().round(2)
# Out:
#                      Valor
# Bairro
# Abolição           1195.33
# Alto da Boa Vista  3966.67
# Anchieta            875.00
# Andaraí            1464.71
# Anil               2048.87
# ...                    ...
# Vila Valqueire     1769.58
# Vila da Penha      1260.58
# Vista Alegre       1114.38
# Zumbi              2150.00
# Água Santa          861.11
#
# [152 rows x 1 columns]

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       500.0  60.0     42.50   Apartamento
# 1         0.0   0.0     70.00          Casa
# 2       390.0  20.0     53.33   Apartamento
# 3       230.0   0.0     16.67   Apartamento
# 4       301.0  17.0     26.00   Apartamento

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %% [markdown]
# ## Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe()
# Out:
#                    count         mean          std     min     25%     50%  \
# Bairro
# Abolição            15.0  1195.333333   425.321167   800.0   900.0  1180.0
# Alto da Boa Vista    6.0  3966.666667  5513.589273   600.0  1150.0  1725.0
# Anchieta             4.0   875.000000   132.287566   700.0   812.5   900.0
# Andaraí             97.0  1464.711340   408.105582   700.0  1200.0  1400.0
# Anil                71.0  2048.873239  1523.974643   300.0  1100.0  1500.0
# ...                  ...          ...          ...     ...     ...     ...
# Vila Valqueire      48.0  1769.583333  2203.013370   800.0  1000.0  1250.0
# Vila da Penha      104.0  1260.576923   644.656644   450.0   900.0  1100.0
# Vista Alegre        16.0  1114.375000   199.598555   700.0  1012.5  1200.0
# Zumbi                2.0  2150.000000   777.817459  1600.0  1875.0  2150.0
# Água Santa           9.0   861.111111   174.602724   600.0   800.0   850.0
#
#                       75%      max
# Bairro
# Abolição           1200.0   2300.0
# Alto da Boa Vista  3275.0  15000.0
# Anchieta            962.5   1000.0
# Andaraí            1650.0   2950.0
# Anil               2675.0   7000.0
# ...                   ...      ...
# Vila Valqueire     1700.0  16000.0
# Vila da Penha      1302.5   4500.0
# Vista Alegre       1225.0   1400.0
# Zumbi              2425.0   2700.0
# Água Santa          950.0   1200.0
#
# [152 rows x 8 columns]

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns= {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                    Mínimo   Máximo
# Bairro
# Abolição            800.0   2300.0
# Alto da Boa Vista   600.0  15000.0
# Anchieta            700.0   1000.0
# Andaraí             700.0   2950.0
# Anil                300.0   7000.0
# ...                   ...      ...
# Vila Valqueire      800.0  16000.0
# Vila da Penha       450.0   4500.0
# Vista Alegre        700.0   1400.0
# Zumbi              1600.0   2700.0
# Água Santa          600.0   1200.0
#
# [152 rows x 2 columns]

# %% [markdown]
# **E se fosse para todos os bairros? Ainda seria fácil de verificar via dataframe resultante?**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]
dados
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete       Copacabana        1      0       0    40
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9             Apartamento       Copacabana        1      0       1    40
# 10              Quitinete       Copacabana        1      0       0    27
# 11            Apartamento       Copacabana        4      3       1   243
# ...                   ...              ...      ...    ...     ...   ...
# 21816         Apartamento           Leblon        3      0       1    80
# 21817         Apartamento          Ipanema        3      1       2   150
# 21818         Apartamento           Tijuca        1      0       0    28
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 21825         Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0       1700.0       500.0    60.0     42.50   Apartamento
# 5      22000.0         0.0     0.0     29.33          Casa
# 9       2000.0       561.0    50.0     50.00   Apartamento
# 10      1800.0       501.0     0.0     66.67   Apartamento
# 11     13000.0      2000.0   803.0     53.50   Apartamento
# ...        ...         ...     ...       ...           ...
# 21816   3000.0      1010.0   249.0     37.50   Apartamento
# 21817  15000.0      1400.0   600.0    100.00   Apartamento
# 21818   1000.0       360.0    25.0     35.71   Apartamento
# 21820  15000.0      1711.0  2332.0     33.33          Casa
# 21825   3000.0       760.0     0.0     42.86   Apartamento
#
# [12216 rows x 11 columns]

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color='red')

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color='black')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Valor'].max().plot.bar(color='green')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Máximo do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Máximo do Aluguel por Bairro')

# %%
dados
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete       Copacabana        1      0       0    40
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9             Apartamento       Copacabana        1      0       1    40
# 10              Quitinete       Copacabana        1      0       0    27
# 11            Apartamento       Copacabana        4      3       1   243
# ...                   ...              ...      ...    ...     ...   ...
# 21816         Apartamento           Leblon        3      0       1    80
# 21817         Apartamento          Ipanema        3      1       2   150
# 21818         Apartamento           Tijuca        1      0       0    28
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 21825         Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0       1700.0       500.0    60.0     42.50   Apartamento
# 5      22000.0         0.0     0.0     29.33          Casa
# 9       2000.0       561.0    50.0     50.00   Apartamento
# 10      1800.0       501.0     0.0     66.67   Apartamento
# 11     13000.0      2000.0   803.0     53.50   Apartamento
# ...        ...         ...     ...       ...           ...
# 21816   3000.0      1010.0   249.0     37.50   Apartamento
# 21817  15000.0      1400.0   600.0    100.00   Apartamento
# 21818   1000.0       360.0    25.0     35.71   Apartamento
# 21820  15000.0      1711.0  2332.0     33.33          Casa
# 21825   3000.0       760.0     0.0     42.86   Apartamento
#
# [12216 rows x 11 columns]

# %%
pd.crosstab(dados['Tipo'], dados['Bairro'])
# Out:
# Bairro              Barra da Tijuca  Botafogo  Copacabana  Flamengo  Ipanema  \
# Tipo
# Apartamento                    3282       771        2349       638     1732
# Casa                             83        13           1         0        4
# Casa de Condomínio              496         4           2         0        1
# Casa de Vila                      0        10           2         1        1
# Quitinete                         2        75         290        75       26
#
# Bairro              Leblon  Tijuca
# Tipo
# Apartamento           1222    1046
# Casa                     3      19
# Casa de Condomínio      12       0
# Casa de Vila             0      15
# Quitinete               21      20

# %%
pd.crosstab(dados['Tipo'], dados['Bairro'], normalize=True)*100
# Out:
# Bairro              Barra da Tijuca  Botafogo  Copacabana  Flamengo  \
# Tipo
# Apartamento               26.866405  6.311395   19.228880  5.222659
# Casa                       0.679437  0.106418    0.008186  0.000000
# Casa de Condomínio         4.060249  0.032744    0.016372  0.000000
# Casa de Vila               0.000000  0.081860    0.016372  0.008186
# Quitinete                  0.016372  0.613949    2.373936  0.613949
#
# Bairro                Ipanema     Leblon    Tijuca
# Tipo
# Apartamento         14.178127  10.003274  8.562541
# Casa                 0.032744   0.024558  0.155534
# Casa de Condomínio   0.008186   0.098232  0.000000
# Casa de Vila         0.008186   0.000000  0.122790
# Quitinete            0.212836   0.171906  0.163720

# %%
pd.crosstab(dados['Tipo'], dados['Bairro'], aggfunc='mean', values=dados['Valor'])
# Out:
# Bairro              Barra da Tijuca      Botafogo   Copacabana     Flamengo  \
# Tipo
# Apartamento             5555.670018   9497.491569  4450.551298  4438.445141
# Casa                   14592.072289  12992.307692  8000.000000          NaN
# Casa de Condomínio     15850.266129  11475.000000  5500.000000          NaN
# Casa de Vila                    NaN   4325.000000  4250.000000  4800.000000
# Quitinete               1550.000000   1262.000000  1479.617241  1340.400000
#
# Bairro                   Ipanema        Leblon       Tijuca
# Tipo
# Apartamento          9465.173210   8624.150573  1948.759082
# Casa                10025.000000  28000.000000  7942.105263
# Casa de Condomínio   4000.000000  28250.000000          NaN
# Casa de Vila         6000.000000           NaN  2456.000000
# Quitinete            2044.230769   1961.428571  1086.500000
