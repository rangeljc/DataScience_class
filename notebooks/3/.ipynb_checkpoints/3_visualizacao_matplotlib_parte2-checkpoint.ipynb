# %% [markdown]
# # Aula 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df['espécie'].unique()#df['espécie'].nunique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['espécie'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: espécie, dtype: int64

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_xlabel('Comprimento da Sépala', fontsize= 15)
eixo.set_ylabel('Largura da Sépala', fontsize= 15)
eixo.set_title('Grafico de Dispersão', fontsize= 20, pad=10)
# Out:
# Text(0.5, 1.0, 'Grafico de Dispersão')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_xlabel('Comprimento da Sépala', fontsize= 15)
eixo.set_ylabel('Largura da Sépala', fontsize= 15)
eixo.set_title('Grafico de Dispersão', fontsize= 20, pad=10)
eixo.tick_params(labelsize=15)#aumentar o tamanho do 'tick'

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'g', 'Iris-versicolor': 'b', 'Iris-virginica': 'y'}

for esp in df['espécie'].unique():
    sel = df['espécie'] == esp
    eixo.scatter(df[sel]['comprimento_sépala'], df[sel]['largura_sépala'], color = cores[esp])
    #d=df[sel]
    #eixo.scatter(d['comprimento_sépala'], d['largura_sépala'], color = cores[esp])



#dicionario chave:valor, chave:valor, ...

#selecionar quais instancias/registro sao daquela especie
#plota os dados daquela especie
eixo.set_xlabel('Comprimento da Sépala', fontsize= 15)
eixo.set_ylabel('Largura da Sépala', fontsize= 15)
eixo.set_title('Grafico de Dispersão', fontsize= 20, pad=10)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=25)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'g', 'Iris-versicolor': 'b', 'Iris-virginica': 'y'}

for esp in df['espécie'].unique():
    sel = df['espécie'] == esp
    eixo.scatter(df[sel]['largura_pétala'], df[sel]['largura_sépala'], color = cores[esp])

eixo.set_xlabel('Largura da pétala', fontsize= 15)
eixo.set_ylabel('Largura da Sépala', fontsize= 15)
eixo.set_title('Grafico de Dispersão', fontsize= 20, pad=10)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=25)
plt.show()

# %% [markdown]
# **As vezes pontos podem ficar sobrepostos, marcadores diferentes podem revelar sobreposições**

# %%
#marker - add marcadores
#o parametro 's' altera o tamanho do marcador

fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'g', 'Iris-versicolor': 'b', 'Iris-virginica': 'y'}

mark = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}


for esp in df['espécie'].unique():
    sel = df['espécie'] == esp
    eixo.scatter(df[sel]['comprimento_sépala'], df[sel]['largura_sépala'], 
                 color = cores[esp], marker = mark[esp], s=100)

eixo.set_xlabel('Comprimento da Sépala', fontsize= 15)
eixo.set_ylabel('Largura da Sépala', fontsize= 15)
eixo.set_title('Grafico de Dispersão', fontsize= 20, pad=10)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=25)
plt.show()

# %% [markdown]
# **Análise das variáveis/atributos com boxplot**

# %%
df['largura_sépala'].quantile(0.75)
# Out:
# 3.3

# %%
df['largura_sépala'].median()
# Out:
# 3.0

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df['largura_sépala'])
eixo.set_xticklabels(['Largura da Sépala'])
plt.show()

# %% [markdown]
# **Para todas as variáveis**

# %%
grafico = df.drop('espécie', axis=1)
#eliminar/dropar a coluna (axis=1) 'espécie', pois eh categorica

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(grafico.values)
eixo.set_xticklabels(grafico.columns)

#queremos os valores
#queremos os cabecalhos das colunas
fig.show()

# %%
#Boxplot do Pandas usa matplotlib
plt.figure(figsize=(10,6))
df.boxplot()
plt.show()

# %%
#preencher os boxplots
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(grafico.values, patch_artist = True)
eixo.set_xticklabels(grafico.columns)

fig.show()
# Out:
# C:\Users\10126\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# **Colocando cores diferentes para cada boxplot**

# %%
#preencher os boxplots
eixo.boxplot(grafico.values, patch_artist = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a08b9b0908>,
#   <matplotlib.lines.Line2D at 0x1a08b9bbac8>,
#   <matplotlib.lines.Line2D at 0x1a08b9cac50>,
#   <matplotlib.lines.Line2D at 0x1a08b9cacf8>,
#   <matplotlib.lines.Line2D at 0x1a08b9df470>,
#   <matplotlib.lines.Line2D at 0x1a08b9df7b8>,
#   <matplotlib.lines.Line2D at 0x1a08b9e5b00>,
#   <matplotlib.lines.Line2D at 0x1a08b9e5e48>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a08b9bb198>,
#   <matplotlib.lines.Line2D at 0x1a08b9bb6a0>,
#   <matplotlib.lines.Line2D at 0x1a08b9d7470>,
#   <matplotlib.lines.Line2D at 0x1a08b9d77b8>,
#   <matplotlib.lines.Line2D at 0x1a08b9dfb00>,
#   <matplotlib.lines.Line2D at 0x1a08b9dfe48>,
#   <matplotlib.lines.Line2D at 0x1a08b9e5fd0>,
#   <matplotlib.lines.Line2D at 0x1a08b9ee518>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x1a08b9bbe10>,
#   <matplotlib.patches.PathPatch at 0x1a08b9caeb8>,
#   <matplotlib.patches.PathPatch at 0x1a08b9df278>,
#   <matplotlib.patches.PathPatch at 0x1a08b9e5908>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a08b9ca198>,
#   <matplotlib.lines.Line2D at 0x1a08b9d7b00>,
#   <matplotlib.lines.Line2D at 0x1a08b9dffd0>,
#   <matplotlib.lines.Line2D at 0x1a08b9ee860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a08b9ca320>,
#   <matplotlib.lines.Line2D at 0x1a08b9d7e48>,
#   <matplotlib.lines.Line2D at 0x1a08b9e5518>,
#   <matplotlib.lines.Line2D at 0x1a08b9eeba8>],
#  'means': []}

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

#lista de cores
cores = ['red', 'blue', 'orange', 'green']

#atribuir os objetos boxplots
caixas = eixo.boxplot(grafico.values, patch_artist = True)
eixo.set_xticklabels(grafico.columns)

#para cada caixa, cor iterar com zip de forma conjunta nas (caixas, cores)
#associa uma caixa com uma cor

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)
    
#caixas['boxes'][0].set(color='cyan')

# %% [markdown]
# **Modificar os marcadores para os outliers(fliers)**

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

# %% [markdown]
# **Histogramas**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

#o 'bins' ná prática aumenta a quantidade de barras
#o 'density' calcula a integral e traça uma linha com a área da distribuição.
eixo.hist(df['comprimento_pétala'], bins=50, density = True)#, orientation = 'horizontal')
#as mesmas configuraçãoes servem para o histograma.

plt.show()

# %% [markdown]
# **Aumentar o detalhamento -> quantidade de barras**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# %% [markdown]
# **Normalizar o histograma**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

#integral da area eh 1

# %% [markdown]
# **Mudando a orientação**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# %% [markdown]
# # Aula 5

# %% [markdown]
# **Anotar os valores de média e desvio padrão no gráfico**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins=20, density = True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da Pépala', fontsize= 15)
eixo.grid(True)

eixo.annotate(f'$\mu={mu:.2f}$\n$\sigma={sigma:.2f}$', xy=(1,1), fontsize=10)

plt.show()

# %% [markdown]
# **Indicar com linha vertical a média**

# %%
#add linha vertical
#add anotacao

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins=20, density = True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da Pépala', fontsize= 15)
eixo.grid(True)

#eixo.annotate(f'$\mu={mu:.2f}$\n$\sigma={sigma:.2f}$', xy=(4.5, 20), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

md = df['comprimento_pétala'].median()

eixo.hist(df['comprimento_pétala'], bins=20, density = True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da Pépala', fontsize= 15)
eixo.grid(True)

#eixo.annotate(f'$\mu={mu:.2f}$\n$\sigma={sigma:.2f}$', xy=(4.5, 20), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-1.3, 10), fontsize=20)

eixo.axvline(md, color='g', linestyle='--')
eixo.annotate('mediana', xy=(md+0.2, 10), fontsize=20)

plt.show()

# %% [markdown]
# **Análise por espécie e comparação**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_iv = df.query('espécie == "Iris-versicolor"')

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

md = df_iv['comprimento_pétala'].median()

eixo.hist(df_iv['comprimento_pétala'], bins=20, density = True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da Pépala', fontsize= 15)
eixo.grid(True)

eixo.annotate(f'$\mu={mu:.2f}$\n$\sigma={sigma:.2f}$', xy=(4.5, 6), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('Media', xy=(mu-0.1,10), fontsize=20, color='k')

eixo.axvline(md, color='g', linestyle='--')
eixo.annotate('mediana', xy=(md+0.7, 6), fontsize=10)

#fig.savefig('histograma.png', bbox_inches='tight')

#plt.show()
# Out:
# Text(5.05, 6, 'mediana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

# %% [markdown]
# **Modo 1**

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivg.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png',
                               'histograma_ivg.png']):
    combinada.paste(imagem, (intervalo, 0))
    intervalo += largura
    
combinada.save('combinada.png')

# %%
combinada

# %% [markdown]
# **Modo 2**

# %%
#funcao
def plot_hist(df, especies, xy_mu_std, xy_mu, xy_md):
  fig, eixos = plt.subplots(1,len(especies))
  fig.set_size_inches(22,8)

  for especie, eixo in zip(especies, eixos):

    df_tmp = df[df['espécie'] == especie]

    mu, sigma = df_tmp['comprimento_pétala'].mean(), df_tmp['comprimento_pétala'].std()
    eixo.hist(df_tmp['comprimento_pétala'], bins=20)
    eixo.set_title(especie, fontsize=15, pad=10)
    eixo.set_xlabel('Comprimento da pétala', fontsize=15)
    eixo.grid(True)
    
    eixo.annotate(f'$\mu = {mu:.2f}$\n$\sigma = {sigma:.2f}$',xy=xy_mu_std[especie], fontsize=20)

    eixo.axvline(mu, color = 'k', linestyle='--')
    eixo.annotate('média', xy=xy_mu[especie], fontsize=20)

    eixo.axvline(df_tmp['comprimento_pétala'].median(), color='g', linestyle='--')
    eixo.annotate('mediana', xy=xy_md[especie], fontsize=20,
                  color='g')

    fig.savefig(f'histograma_{especie}.png', bbox_inches='tight')

# %%
#funcao auxiliar
def mu_md(df, especie):
  sel = df['espécie']==especie
  return df[sel]['comprimento_pétala'].mean(), df[sel]['comprimento_pétala'].median()

# %%
#subplot

especies = ['Iris-versicolor','Iris-setosa', 'Iris-virginica']
mu_iv, md_iv = mu_md(df, especies[0])
mu_is, md_is = mu_md(df, especies[1])
mu_ivc, md_ivc = mu_md(df,especies[2])

xy_mu_std = {especies[0]:(4.6, 6),
             especies[1]:(1.7, 7),
             especies[2]:(6.3, 7)
            }

xy_mu = {especies[0]:(mu_iv-0.5, 5.5),
         especies[1]:(mu_is-0.2, 13.5),
         especies[2]:(mu_ivc, 8)
        }

xy_md = {especies[0]:(md_iv-0.7, 6.5),
         especies[1]:(md_is+0.05, 12),
         especies[2]:(md_ivc, 7)
        }

plot_hist(df,especies,xy_mu_std, xy_mu, xy_md)
